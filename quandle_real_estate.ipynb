# %%
import pandas as pd
import numpy as np
import folium
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .master("local[*]") \
    .appName('My First Spark application') \
    .getOrCreate() 

sc = spark.sparkContext

# %%
df1 = spark.read.csv('ZILLOW-DATA.csv', header = True)
df2 = spark.read.csv('ZILLOW-REGIONS.csv', header = True)
df3 = spark.read.csv('ZILLOW-INDICATORS.csv', header = True)

# %%
df1.createOrReplaceTempView("data")
df2.createOrReplaceTempView("regions")
df3.createOrReplaceTempView("indicators")

# %%
query = """
SELECT data.indicator_id, data.region_id, regions.region_type, regions.region, indicators.indicator, indicators.category, data.date, data.value
    FROM data, regions, indicators
    where data.indicator_id = indicators.indicator_id and data.region_id = regions.region_id
"""
result = spark.sql(query)
result.show()
# Out:
# +------------+---------+-----------+--------------------+--------------------+-----------+----------+--------+
# |indicator_id|region_id|region_type|              region|           indicator|   category|      date|   value|
# +------------+---------+-----------+--------------------+--------------------+-----------+----------+--------+
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-01-31|164988.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-02-28|164998.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-03-31|165721.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-04-30|167105.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-05-31|169868.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-06-30|172571.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-07-31|174991.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-08-31|176223.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-09-30|177270.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-10-31|179215.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-11-30|181214.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2005-12-31|183392.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-01-31|184637.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-02-28|186794.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-03-31|188116.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-04-30|188989.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-05-31|188323.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-06-30|187415.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-07-31|187126.0|
# |        ZSFH|    99999|        zip|98847; WA; Wenatc...|ZHVI Single-Famil...|Home values|2006-08-31|189865.0|
# +------------+---------+-----------+--------------------+--------------------+-----------+----------+--------+
# only showing top 20 rows

# %%
df = result.toPandas()
df.head()
# Out:
#   indicator_id region_id region_type  \
# 0         ZSFH     99999         zip
# 1         ZSFH     99999         zip
# 2         ZSFH     99999         zip
# 3         ZSFH     99999         zip
# 4         ZSFH     99999         zip
#
#                                            region  \
# 0  98847; WA; Wenatchee; Chelan County; Peshastin
# 1  98847; WA; Wenatchee; Chelan County; Peshastin
# 2  98847; WA; Wenatchee; Chelan County; Peshastin
# 3  98847; WA; Wenatchee; Chelan County; Peshastin
# 4  98847; WA; Wenatchee; Chelan County; Peshastin
#
#                                   indicator     category        date     value
# 0  ZHVI Single-Family Homes Time Series ($)  Home values  2005-01-31  164988.0
# 1  ZHVI Single-Family Homes Time Series ($)  Home values  2005-02-28  164998.0
# 2  ZHVI Single-Family Homes Time Series ($)  Home values  2005-03-31  165721.0
# 3  ZHVI Single-Family Homes Time Series ($)  Home values  2005-04-30  167105.0
# 4  ZHVI Single-Family Homes Time Series ($)  Home values  2005-05-31  169868.0

# %%
def splitaddress(x,n):
    try:
        return x.split('; ')[n]
    except:
        return np.NaN
    
df['zip'] = df.region.apply(lambda x: splitaddress(x,0))
df['state'] = df.region.apply(lambda x: splitaddress(x,1))
df['city'] = df.region.apply(lambda x: splitaddress(x,2))
df['county'] = df.region.apply(lambda x: splitaddress(x,3))
df['community'] = df.region.apply(lambda x: splitaddress(x,4))
df.head()
# Out:
#   indicator_id region_id region_type  \
# 0         ZSFH     99999         zip
# 1         ZSFH     99999         zip
# 2         ZSFH     99999         zip
# 3         ZSFH     99999         zip
# 4         ZSFH     99999         zip
#
#                                            region  \
# 0  98847; WA; Wenatchee; Chelan County; Peshastin
# 1  98847; WA; Wenatchee; Chelan County; Peshastin
# 2  98847; WA; Wenatchee; Chelan County; Peshastin
# 3  98847; WA; Wenatchee; Chelan County; Peshastin
# 4  98847; WA; Wenatchee; Chelan County; Peshastin
#
#                                   indicator     category        date  \
# 0  ZHVI Single-Family Homes Time Series ($)  Home values  2005-01-31
# 1  ZHVI Single-Family Homes Time Series ($)  Home values  2005-02-28
# 2  ZHVI Single-Family Homes Time Series ($)  Home values  2005-03-31
# 3  ZHVI Single-Family Homes Time Series ($)  Home values  2005-04-30
# 4  ZHVI Single-Family Homes Time Series ($)  Home values  2005-05-31
#
#       value    zip state       city         county  community
# 0  164988.0  98847    WA  Wenatchee  Chelan County  Peshastin
# 1  164998.0  98847    WA  Wenatchee  Chelan County  Peshastin
# 2  165721.0  98847    WA  Wenatchee  Chelan County  Peshastin
# 3  167105.0  98847    WA  Wenatchee  Chelan County  Peshastin
# 4  169868.0  98847    WA  Wenatchee  Chelan County  Peshastin

# %%
# https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/table/
zipcode = pd.read_json('us-zip-code-latitude-and-longitude.json')['fields']
zipcode = pd.DataFrame(zipcode.values.tolist())
zipcode.head()
# Out:
#               city    zip  dst                 geopoint  longitude state  \
# 0           Eudora  66025    1   [38.917032, -95.06455]  -95.06455    KS
# 1          Savanna  74565    1   [34.831398, -95.83967]  -95.83967    OK
# 2        Beckville  75631    1   [32.237924, -94.46427]  -94.46427    TX
# 3  Rancho Santa Fe  92067    1  [33.016492, -117.20264] -117.20264    CA
# 4        San Diego  92119    1   [32.80225, -117.02431] -117.02431    CA
#
#     latitude  timezone
# 0  38.917032        -6
# 1  34.831398        -6
# 2  32.237924        -6
# 3  33.016492        -8
# 4  32.802250        -8

# %%
df2 = pd.merge(df, zipcode, how = 'left', on = 'zip')
df2.head()
# Out:
#   indicator_id region_id region_type  \
# 0         ZSFH     99999         zip
# 1         ZSFH     99999         zip
# 2         ZSFH     99999         zip
# 3         ZSFH     99999         zip
# 4         ZSFH     99999         zip
#
#                                            region  \
# 0  98847; WA; Wenatchee; Chelan County; Peshastin
# 1  98847; WA; Wenatchee; Chelan County; Peshastin
# 2  98847; WA; Wenatchee; Chelan County; Peshastin
# 3  98847; WA; Wenatchee; Chelan County; Peshastin
# 4  98847; WA; Wenatchee; Chelan County; Peshastin
#
#                                   indicator     category        date  \
# 0  ZHVI Single-Family Homes Time Series ($)  Home values  2005-01-31
# 1  ZHVI Single-Family Homes Time Series ($)  Home values  2005-02-28
# 2  ZHVI Single-Family Homes Time Series ($)  Home values  2005-03-31
# 3  ZHVI Single-Family Homes Time Series ($)  Home values  2005-04-30
# 4  ZHVI Single-Family Homes Time Series ($)  Home values  2005-05-31
#
#       value    zip state_x     city_x         county  community     city_y  \
# 0  164988.0  98847      WA  Wenatchee  Chelan County  Peshastin  Peshastin
# 1  164998.0  98847      WA  Wenatchee  Chelan County  Peshastin  Peshastin
# 2  165721.0  98847      WA  Wenatchee  Chelan County  Peshastin  Peshastin
# 3  167105.0  98847      WA  Wenatchee  Chelan County  Peshastin  Peshastin
# 4  169868.0  98847      WA  Wenatchee  Chelan County  Peshastin  Peshastin
#
#    dst                 geopoint  longitude state_y   latitude  timezone
# 0  1.0  [47.552462, -120.60457] -120.60457      WA  47.552462      -8.0
# 1  1.0  [47.552462, -120.60457] -120.60457      WA  47.552462      -8.0
# 2  1.0  [47.552462, -120.60457] -120.60457      WA  47.552462      -8.0
# 3  1.0  [47.552462, -120.60457] -120.60457      WA  47.552462      -8.0
# 4  1.0  [47.552462, -120.60457] -120.60457      WA  47.552462      -8.0

# %%
k = []
df3 = df2.copy()
df3.sort_values('date', inplace = True)
df3.date = pd.to_datetime(df3.date)
df3[df3.date >= pd.datetime(2010,1,1)]
df3 = df3[df3['latitude'].notnull()]
df3.value = df3.value.astype('float')
df3['value'] = df3['value'] / df3['value'].max()
days = df3.date.unique()
for i in days:
    k.append(df3[df3.date == i][['latitude','longitude','value']].values.tolist())
k[0]
# Out:
# C:\Users\dy090\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """
# [[45.712623, -122.63419, 0.2975656899546193],
#  [45.604075, -122.51035, 0.2764388060955796],
#  [45.627459, -122.52023, 0.23853402151381028],
#  [45.709555, -122.68473, 0.2972925654098269],
#  [45.67309, -122.51319, 0.22549407529833604],
#  [45.594465, -122.28112, 0.2800016807664295],
#  [45.681271, -122.66712, 0.24238577791472912],
#  [45.928662, -122.70284, 0.22227260630847667],
#  [45.843674, -122.39221, 0.27264832763740265]]

# %%
m=folium.Map(location=[df2.latitude[0],df2.longitude[0]], tiles='stamentoner', zoom_start=6)
folium.plugins.HeatMapWithTime(k).add_to(m)
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
